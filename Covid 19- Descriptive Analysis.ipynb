# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
vaccination = pd.read_csv('/content/drive/MyDrive/Education/ST.CLAIR_COLLEGE/Project_datasets/vaccinations.csv')

# %%
vaccination.head()
# Out:
#          date location_key  new_persons_vaccinated  \
# 0  25-01-2021           AD                     NaN
# 1  01-02-2021           AD                   460.0
# 2  10-02-2021           AD                   255.0
# 3  12-02-2021           AD                   331.0
# 4  19-02-2021           AD                   519.0
#
#    cumulative_persons_vaccinated  new_persons_fully_vaccinated  \
# 0                          576.0                           NaN
# 1                         1036.0                           NaN
# 2                         1291.0                           NaN
# 3                         1622.0                           NaN
# 4                         2141.0                           NaN
#
#    cumulative_persons_fully_vaccinated  new_vaccine_doses_administered  \
# 0                                  NaN                             NaN
# 1                                  NaN                           460.0
# ...

# %%
GDP = pd.read_csv('/content/drive/MyDrive/Education/ST.CLAIR_COLLEGE/Project_datasets/world-gdp-gross-domestic-product.csv')

# %%
GDP.head()
# Out:
#          date   GDP ( Billions of US $)   Per Capita (US $)   Annual % Change
# 0  1960-12-31               1392.276589            459.2600               NaN
# 1  1961-12-31               1448.625355            471.4794            3.7900
# 2  1962-12-31               1550.548210            495.8684            5.3160
# 3  1963-12-31               1671.614362            523.4413            5.1854
# 4  1964-12-31               1830.292049            561.3501            6.5583
