# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
vaccination = pd.read_csv('/content/drive/MyDrive/Education/ST.CLAIR_COLLEGE/Project_datasets/vaccinations.csv')

# %%
vaccination.head()
# Out:
#          date location_key  new_persons_vaccinated  \
# 0  25-01-2021           AD                     NaN
# 1  01-02-2021           AD                   460.0
# 2  10-02-2021           AD                   255.0
# 3  12-02-2021           AD                   331.0
# 4  19-02-2021           AD                   519.0
#
#    cumulative_persons_vaccinated  new_persons_fully_vaccinated  \
# 0                          576.0                           NaN
# 1                         1036.0                           NaN
# 2                         1291.0                           NaN
# 3                         1622.0                           NaN
# 4                         2141.0                           NaN
#
#    cumulative_persons_fully_vaccinated  new_vaccine_doses_administered  \
# 0                                  NaN                             NaN
# 1                                  NaN                           460.0
# ...

# %%
USGDP = pd.read_csv('/content/drive/MyDrive/Education/ST.CLAIR_COLLEGE/Project_datasets/united-states-gdp-gross-domestic-product.csv')

# %%
USGDP.head()
# Out:
#          date   GDP ( Billions of US $)   Per Capita (US $)   Annual % Change
# 0  1960-12-31                     543.3           3007.1234               NaN
# 1  1961-12-31                     563.3           3066.5629               2.3
# 2  1962-12-31                     605.1           3243.8431               6.1
# 3  1963-12-31                     638.6           3374.5152               4.4
# 4  1964-12-31                     685.8           3573.9412               5.8

# %%
US_employement = pd.read_csv('/content/drive/MyDrive/Education/ST.CLAIR_COLLEGE/Project_datasets/us-national-unemployment-rate.csv')

# %%
US_employement.head()
# Out:
#          date   value
# 0  1948-01-01     3.4
# 1  1948-02-01     3.8
# 2  1948-03-01     4.0
# 3  1948-04-01     3.9
# 4  1948-05-01     3.5
